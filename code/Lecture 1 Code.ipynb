# %%
def add(a, b):
    return a+b

def mul(a, b):
    return a * b

# %% [markdown]
# ### Expressions
#
# #### An expression describes a computation and evaluates to a value

# %%
1+1
# Out:
# 2

# %%
2*2
# Out:
# 4

# %%
5/2
# Out:
# 2.5

# %% [markdown]
# #### Call Expression: All expressions can use function call notation

# %%
add(2, 3)
# Out:
# 5

# %%
mul(2, 3)
# Out:
# 6

# %% [markdown]
# ### But how is it evaluated?
#
#    ![call%20expression.png](attachment:call%20expression.png)

# %% [markdown]
# ### Evaluation procedure for call expressions:
# 1. Evaluate the operator and then the operand subexpressions
# 2. Apply the function that is the value of the operator to the arguments that are the values of the operands

# %% [markdown]
# $mul(add(2, 3), add(1, 2))$
